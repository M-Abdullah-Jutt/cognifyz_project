# %% [markdown]
# # Task No 7

# %% [markdown]
# ### Common Information Sources

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv('Data_set_2.csv')
data
# Out:
#     gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0   Female   34                Yes             1              2           5
# 1   Female   23                Yes             4              3           2
# 2     Male   30                Yes             3              6           4
# 3     Male   22                Yes             2              1           3
# 4   Female   24                 No             2              1           3
# 5   Female   24                 No             7              5           4
# 6   Female   27                Yes             3              6           4
# 7     Male   21                Yes             2              3           7
# 8     Male   35                Yes             2              4           7
# 9     Male   31                Yes             1              3           7
# 10  Female   35                Yes             2              4           7
# ...

# %%
data['Source']
# Out:
# 0     Newspapers and Magazines
# 1        Financial Consultants
# 2                   Television
# 3                     Internet
# 4                     Internet
# 5                     Internet
# 6        Financial Consultants
# 7     Newspapers and Magazines
# 8                   Television
# 9     Newspapers and Magazines
# 10       Financial Consultants
# 11       Financial Consultants
# 12                    Internet
# 13    Newspapers and Magazines
# 14       Financial Consultants
# 15    Newspapers and Magazines
# 16                  Television
# 17       Financial Consultants
# 18    Newspapers and Magazines
# 19    Newspapers and Magazines
# 20       Financial Consultants
# 21    Newspapers and Magazines
# 22       Financial Consultants
# 23       Financial Consultants
# 24    Newspapers and Magazines
# 25       Financial Consultants
# 26       Financial Consultants
# 27                  Television
# 28                  Television
# 29    Newspapers and Magazines
# ...

# %%
data['Source'].value_counts()
# Out:
# Source
# Financial Consultants       16
# Newspapers and Magazines    14
# Television                   6
# Internet                     4
# Name: count, dtype: int64

# %% [markdown]
# # Task No 8

# %% [markdown]
# ### Investment Duration

# %%
duration = data['Duration']
duration
# Out:
# 0             1-3 years
# 1     More than 5 years
# 2             3-5 years
# 3      Less than 1 year
# 4      Less than 1 year
# 5             1-3 years
# 6             3-5 years
# 7             3-5 years
# 8             1-3 years
# 9             3-5 years
# 10            3-5 years
# 11            1-3 years
# 12            1-3 years
# 13            1-3 years
# 14            1-3 years
# 15            1-3 years
# 16            1-3 years
# 17            1-3 years
# 18            1-3 years
# 19            3-5 years
# 20            3-5 years
# 21            3-5 years
# 22            3-5 years
# 23            3-5 years
# 24            3-5 years
# 25            3-5 years
# 26            3-5 years
# 27            1-3 years
# 28            1-3 years
# 29            3-5 years
# 30            1-3 years
# 31            3-5 years
# 32            3-5 years
# 33            1-3 years
# 34            1-3 years
# 35            3-5 years
# 36            1-3 years
# 37            3-5 years
# ...

# %% [markdown]
# First we need to replace string with integer values.

# %%
duration = duration.replace('1-3 years', 2)

# %%
duration = duration.replace('3-5 years', 4)

# %%
duration
# Out:
# 0                     2
# 1     More than 5 years
# 2                     4
# 3      Less than 1 year
# 4      Less than 1 year
# 5                     2
# 6                     4
# 7                     4
# 8                     2
# 9                     4
# 10                    4
# 11                    2
# 12                    2
# 13                    2
# 14                    2
# 15                    2
# 16                    2
# 17                    2
# 18                    2
# 19                    4
# 20                    4
# 21                    4
# 22                    4
# 23                    4
# 24                    4
# 25                    4
# 26                    4
# 27                    2
# 28                    2
# 29                    4
# 30                    2
# 31                    4
# 32                    4
# 33                    2
# 34                    2
# 35                    4
# 36                    2
# 37                    4
# ...

# %%
duration = duration.replace('Less than 1 year', 0.5)

# %%
duration = duration.replace('More than 5 years', 6)
# Out:
# C:\Users\star\AppData\Local\Temp\ipykernel_14176\1852976643.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   duration = duration.replace('More than 5 years', 6)

# %%
duration
# Out:
# 0     2.0
# 1     6.0
# 2     4.0
# 3     0.5
# 4     0.5
# 5     2.0
# 6     4.0
# 7     4.0
# 8     2.0
# 9     4.0
# 10    4.0
# 11    2.0
# 12    2.0
# 13    2.0
# 14    2.0
# 15    2.0
# 16    2.0
# 17    2.0
# 18    2.0
# 19    4.0
# 20    4.0
# 21    4.0
# 22    4.0
# 23    4.0
# 24    4.0
# 25    4.0
# 26    4.0
# 27    2.0
# 28    2.0
# 29    4.0
# 30    2.0
# 31    4.0
# 32    4.0
# 33    2.0
# 34    2.0
# 35    4.0
# 36    2.0
# 37    4.0
# 38    2.0
# 39    4.0
# Name: Duration, dtype: float64

# %%
duration.mode()
# Out:
# 0    4.0
# Name: Duration, dtype: float64

# %%
duration.describe()
# Out:
# count    40.000000
# mean      2.975000
# std       1.224483
# min       0.500000
# 25%       2.000000
# 50%       3.000000
# 75%       4.000000
# max       6.000000
# Name: Duration, dtype: float64

# %%
duration.median()
# Out:
# np.float64(3.0)

# %% [markdown]
# # Task No 9

# %% [markdown]
# ### Expectations from Investment.

# %% [markdown]
# ## data.head()

# %%
expectation = data['Expect']
expectation
# Out:
# 0     20%-30%
# 1     20%-30%
# 2     20%-30%
# 3     10%-20%
# 4     20%-30%
# 5     30%-40%
# 6     20%-30%
# 7     20%-30%
# 8     20%-30%
# 9     30%-40%
# 10    20%-30%
# 11    20%-30%
# 12    20%-30%
# 13    20%-30%
# 14    20%-30%
# 15    20%-30%
# 16    20%-30%
# 17    20%-30%
# 18    20%-30%
# 19    20%-30%
# 20    20%-30%
# 21    20%-30%
# 22    20%-30%
# 23    20%-30%
# 24    30%-40%
# 25    20%-30%
# 26    20%-30%
# 27    20%-30%
# 28    20%-30%
# 29    10%-20%
# 30    10%-20%
# 31    20%-30%
# 32    30%-40%
# 33    20%-30%
# 34    20%-30%
# 35    20%-30%
# 36    20%-30%
# 37    30%-40%
# 38    20%-30%
# 39    20%-30%
# Name: Expect, dtype: object

# %%
expectation.value_counts()
# Out:
# Expect
# 20%-30%    32
# 30%-40%     5
# 10%-20%     3
# Name: count, dtype: int64

# %% [markdown]
# 30%-40% indicates a high-risk investment with the potential for substantial growth.
#
# 20%-30% suggests a moderate level of risk with the potential for good returns.
#
# 10%-20% This range indicates lower-risk investments with more moderate return expectations.

# %% [markdown]
# # Task No 10

# %% [markdown]
# ### Correlation Analysis

# %%
data = pd.read_csv('Data_set_2.csv')
data
# Out:
#     gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0   Female   34                Yes             1              2           5
# 1   Female   23                Yes             4              3           2
# 2     Male   30                Yes             3              6           4
# 3     Male   22                Yes             2              1           3
# 4   Female   24                 No             2              1           3
# 5   Female   24                 No             7              5           4
# 6   Female   27                Yes             3              6           4
# 7     Male   21                Yes             2              3           7
# 8     Male   35                Yes             2              4           7
# 9     Male   31                Yes             1              3           7
# 10  Female   35                Yes             2              4           7
# ...

# %%
numeric_data = data.select_dtypes(include=['number'])

# %%
numeric_correlation = numeric_data.corr()
numeric_correlation
# Out:
#                        age  Mutual_Funds  Equity_Market  Debentures  \
# age               1.000000     -0.123914       0.246840    0.326638
# Mutual_Funds     -0.123914      1.000000       0.332043   -0.351495
# Equity_Market     0.246840      0.332043       1.000000   -0.016898
# Debentures        0.326638     -0.351495      -0.016898    1.000000
# Government_Bonds -0.093632     -0.114198      -0.237420    0.430323
# Fixed_Deposits   -0.033685     -0.031604      -0.238705   -0.470791
# PPF              -0.263167     -0.193665      -0.429003   -0.511169
# Gold             -0.057952     -0.401830      -0.050027   -0.137195
#
#                   Government_Bonds  Fixed_Deposits       PPF      Gold
# age                      -0.093632       -0.033685 -0.263167 -0.057952
# Mutual_Funds             -0.114198       -0.031604 -0.193665 -0.401830
# Equity_Market            -0.237420       -0.238705 -0.429003 -0.050027
# Debentures                0.430323       -0.470791 -0.511169 -0.137195
# ...

# %%
col1 = data['age']

# %%
age_duration = col1.corr(duration)
print(age_duration)
# Out:
# 0.05175571656968983

# %% [markdown]
# Correlation between Age and Duration is very weak.

# %%
x=data['age']
y=duration

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=x, y=y, color='red')
plt.title('Scatter Plot of Age vs Duration')
plt.xlabel('Age')
plt.ylabel('Duration')
plt.show()
