# %% [markdown]
# # Task No 3

# %% [markdown]
# ### Descriptive Statistics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Data_set_2.csv')
data
# Out:
#     gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0   Female   34                Yes             1              2           5
# 1   Female   23                Yes             4              3           2
# 2     Male   30                Yes             3              6           4
# 3     Male   22                Yes             2              1           3
# 4   Female   24                 No             2              1           3
# 5   Female   24                 No             7              5           4
# 6   Female   27                Yes             3              6           4
# 7     Male   21                Yes             2              3           7
# 8     Male   35                Yes             2              4           7
# 9     Male   31                Yes             1              3           7
# 10  Female   35                Yes             2              4           7
# ...

# %%
num_columns = data.select_dtypes(include='int')
num_columns
# Out:
#     age  Mutual_Funds  Equity_Market  Debentures  Government_Bonds  \
# 0    34             1              2           5                 3
# 1    23             4              3           2                 1
# 2    30             3              6           4                 2
# 3    22             2              1           3                 7
# 4    24             2              1           3                 6
# 5    24             7              5           4                 6
# 6    27             3              6           4                 2
# 7    21             2              3           7                 4
# 8    35             2              4           7                 5
# 9    31             1              3           7                 4
# 10   35             2              4           7                 5
# 11   29             2              5           7                 6
# 12   21             1              2           3                 4
# ...

# %%
data.describe()
# Out:
#              age  Mutual_Funds  Equity_Market  Debentures  Government_Bonds  \
# count  40.000000     40.000000      40.000000   40.000000         40.000000
# mean   27.800000      2.550000       3.475000    5.750000          4.650000
# std     3.560467      1.197219       1.131994    1.675617          1.369072
# min    21.000000      1.000000       1.000000    1.000000          1.000000
# 25%    25.750000      2.000000       3.000000    5.000000          4.000000
# 50%    27.000000      2.000000       4.000000    6.500000          5.000000
# 75%    30.000000      3.000000       4.000000    7.000000          5.000000
# max    35.000000      7.000000       6.000000    7.000000          7.000000
#
#        Fixed_Deposits        PPF       Gold
# count       40.000000  40.000000  40.000000
# mean         3.575000   2.025000   5.975000
# std          1.795828   1.609069   1.143263
# min          1.000000   1.000000   2.000000
# 25%          2.750000   1.000000   6.000000
# ...

# %%
num_columns.mean()
# Out:
# age                 27.800
# Mutual_Funds         2.550
# Equity_Market        3.475
# Debentures           5.750
# Government_Bonds     4.650
# Fixed_Deposits       3.575
# PPF                  2.025
# Gold                 5.975
# dtype: float64

# %%
num_columns.median()
# Out:
# age                 27.0
# Mutual_Funds         2.0
# Equity_Market        4.0
# Debentures           6.5
# Government_Bonds     5.0
# Fixed_Deposits       3.5
# PPF                  1.0
# Gold                 6.0
# dtype: float64

# %%
num_columns.mode()
# Out:
#    age  Mutual_Funds  Equity_Market  Debentures  Government_Bonds  \
# 0   27             2              4           7                 5
#
#    Fixed_Deposits  PPF  Gold
# 0               3    1     6

# %%
num_columns.var()
# Out:
# age                 12.676923
# Mutual_Funds         1.433333
# Equity_Market        1.281410
# Debentures           2.807692
# Government_Bonds     1.874359
# Fixed_Deposits       3.225000
# PPF                  2.589103
# Gold                 1.307051
# dtype: float64

# %%
num_columns.std()
# Out:
# age                 3.560467
# Mutual_Funds        1.197219
# Equity_Market       1.131994
# Debentures          1.675617
# Government_Bonds    1.369072
# Fixed_Deposits      1.795828
# PPF                 1.609069
# Gold                1.143263
# dtype: float64

# %% [markdown]
# # Task No 4

# %% [markdown]
# ### Most Preferred Investment Avenue

# %%
# Python does not have separate functions for checking frequency and occurrence.

highest_avenue = data['Avenue']
highest_avenue
# Out:
# 0               Mutual Fund
# 1               Mutual Fund
# 2                    Equity
# 3                    Equity
# 4                    Equity
# 5               Mutual Fund
# 6                    Equity
# 7               Mutual Fund
# 8                    Equity
# 9            Fixed Deposits
# 10              Mutual Fund
# 11              Mutual Fund
# 12              Mutual Fund
# 13              Mutual Fund
# 14           Fixed Deposits
# 15              Mutual Fund
# 16           Fixed Deposits
# 17              Mutual Fund
# 18              Mutual Fund
# 19           Fixed Deposits
# 20              Mutual Fund
# 21                   Equity
# 22              Mutual Fund
# 23    Public Provident Fund
# 24    Public Provident Fund
# 25              Mutual Fund
# 26              Mutual Fund
# 27           Fixed Deposits
# 28                   Equity
# 29              Mutual Fund
# 30              Mutual Fund
# 31           Fixed Deposits
# 32                   Equity
# ...

# %%
highest_avenue.value_counts()
# Out:
# Avenue
# Mutual Fund              18
# Equity                   10
# Fixed Deposits            9
# Public Provident Fund     3
# Name: count, dtype: int64
